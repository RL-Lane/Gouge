# %%
import glob
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import seaborn as sns
import seaborn as sb
from config import gkey

gmaps.configure(api_key=gkey)

# %%
csv_file = '../Resources/0-200.csv'
car_data1 = pd.read_csv(csv_file)
car_data1 = car_data1.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data1.head()
# Out:
#   Make:  Model:  Year:       Body type:          Exterior color:  \
# 0  Ford  Bronco   2022  SUV / crossover                 Race Red
# 1  Ford  Bronco   2022  SUV / crossover              CACTUS GRAY
# 2  Ford  Bronco   2022  SUV / crossover           Blue (Area 51)
# 3  Ford  Bronco   2022  SUV / crossover           Blue (AREA 51)
# 4  Ford  Bronco   2022  SUV / crossover  HOT Pepper Red MET Tint
#
#                                  Interior color: Mileage:               VIN:  \
# 0                                       Red (Pv)    15 mi  1FMDE5CP9NLB31549
# 1                                    STONE/BLACK     0 mi  1FMEE5DP8NLB35076
# 2  CLOTH SANDSTONE/BLK SEATS BLACK ONYX INTERIOR     0 mi  1FMDE5AH3NLB11244
# 3                                     GRAY/BLACK     0 mi  1FMDE5BH9NLB12171
# 4                                Dark Space Gray     0 mi  1FMDE5BH2NLA84536
#
#     Price:        Dealer Name:                                Dealer Address:  \
# ...

# %%
len(car_data1)
# Out:
# 158

# %%
csv_file = '../Resources/200-400.csv'
car_data2 = pd.read_csv(csv_file)
car_data2 = car_data2.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data2.head()
# Out:
#   Make:    Model:  Year:       Trim:       Body type:  \
# 0  Jeep  Wrangler   2022   Sport 4WD  SUV / crossover
# 1  Jeep  Wrangler   2022   Sport 4WD  SUV / crossover
# 2  Jeep  Wrangler   2022  Willys 4WD  SUV / crossover
# 3  Jeep  Wrangler   2022  Willys 4WD  SUV / crossover
# 4  Jeep  Wrangler   2022  Willys 4WD  SUV / crossover
#
#              Exterior color: Interior color: Mileage:               VIN:  \
# 0            Black Clearcoat           Black     2 mi  1C4GJXAN8NW223826
# 1  Firecracker Red Clearcoat           Black     2 mi  1C4GJXAN1NW223828
# 2               Bright White           Black     0 mi  1C4GJXAN2NW186076
# 3      Sarge Green Clearcoat           Black     4 mi  1C4GJXAG3NW268061
# 4                 Sting-Gray           Black     0 mi  1C4GJXAN4NW186077
#
#     Price:                        Dealer Name:  \
# 0  $41,305                  Freestone Autoplex
# 1  $41,442                  Freestone Autoplex
# 2  $42,065  Richardson Chrysler Jeep Dodge Ram
# ...

# %%
len(car_data2)
# Out:
# 187

# %%
csv_file = '../Resources/400-600.csv'
car_data3 = pd.read_csv(csv_file)
car_data3 = car_data3.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data3.head()
# Out:
#   Make:    Model:  Year:                Trim:       Body type:  \
# 0  Jeep  Wrangler   2022           Sahara 4WD  SUV / crossover
# 1  Jeep  Wrangler   2022  Sahara Altitude 4WD  SUV / crossover
# 2  Jeep  Wrangler   2022          Sport S 4WD  SUV / crossover
# 3  Jeep  Wrangler   2022                  NaN  SUV / crossover
# 4  Jeep  Wrangler   2022                  NaN  SUV / crossover
#
#           Exterior color: Interior color: Mileage:               VIN:  \
# 0  Bright White Clearcoat           Black     4 mi  1C4HJXEGXNW236822
# 1                    Gray           Black     4 mi  1C4HJXEN0NW208154
# 2   Sarge Green Clearcoat           Black     1 mi  1C4HJXDGXNW176400
# 3  Bright White Clearcoat           Black      NaN  1C4HJXDG5NW260009
# 4   Hydro Blue Pearl Coat           Black    12 mi  1C4HJXDG2NW254538
#
#     Price:                          Dealer Name:  \
# 0  $56,305                          Pegasus CDJR
# 1  $56,575        Frisco Chrysler Dodge Jeep Ram
# ...

# %%
len(car_data3)
# Out:
# 182

# %%
csv_file = '../Resources/600-800.csv'
car_data4 = pd.read_csv(csv_file)
car_data4 = car_data4.drop(columns=['Stock #:', 
                                    'Unnamed: 0',
                                    'Delivery:', 
                                    'Price + Delivery:'])
car_data4.head()
# Out:
#   Dealer's Price:    MSRP:                      Location:  Mileage:  \
# 0         $67,935  $67,935        Lamesa, TX\n279 mi away  15 miles
# 1         $69,920  $69,920        Prosper, TX\n35 mi away       ---
# 2         $68,090  $70,225  Lake Charles, LA\n294 mi away       ---
# 3         $68,700  $68,700          Ennis, TX\n43 mi away   3 miles
# 4         $68,287  $70,445  Lake Charles, LA\n294 mi away       ---
#
#        Transmission:         Exterior Color: Interior Color:  \
# 0  8-Speed Automatic  Bright White Clearcoat           Black
# 1  8-Speed Automatic    Sting-Gray Clearcoat           Black
# 2  8-Speed Automatic    Sting-Gray Clearcoat           Black
# 3  8-Speed Automatic         Black Clearcoat           Black
# 4  8-Speed Automatic   Sarge Green Clearcoat           Black
#
#                              Est. Gas Mileage*:  \
# 0  20 MPG City\n20 MPG Highway\n20 MPG Combined
# 1  20 MPG City\n20 MPG Highway\n20 MPG Combined
# ...

# %%
len(car_data4)
# Out:
# 140

# %%
csv_file = '../Resources/800-1000.csv'
car_data5 = pd.read_csv(csv_file)
car_data5 = car_data5.drop(columns=['Stock #:', 
                                    'Unnamed: 0',
                                    'Delivery:', 
                                    'Price + Delivery:'])
car_data5.head()
# Out:
#   Dealer's Price:    MSRP:                 Location: Mileage:  \
# 0         $39,615  $42,715  Houston, TX\n172 mi away  0 miles
# 1         $39,665  $42,765  Houston, TX\n172 mi away  0 miles
# 2         $41,609  $42,765  Houston, TX\n172 mi away  1 miles
# 3         $39,885  $42,985  Houston, TX\n172 mi away  0 miles
# 4         $39,965  $43,065  Houston, TX\n172 mi away  0 miles
#
#        Transmission:               Exterior Color:  \
# 0  8-Speed Automatic  Brown (Limited Edition Gobi)
# 1  8-Speed Automatic                   Sarge Green
# 2  8-Speed Automatic                   Sarge Green
# 3  8-Speed Automatic                         Black
# 4  8-Speed Automatic                   Sarge Green
#
#               Interior Color:                            Est. Gas Mileage*:  \
# 0                       Black  21 MPG City\n24 MPG Highway\n22 MPG Combined
# 1                       Black  21 MPG City\n24 MPG Highway\n22 MPG Combined
# ...

# %%
len(car_data5)
# Out:
# 167

# %%
csv_file = '../Resources/1000-1200.csv'
car_data6 = pd.read_csv(csv_file)
car_data6 = car_data6.drop(columns=['Stock #:', 
                                    'Unnamed: 0',
                                    'Delivery:', 
                                    'Price + Delivery:'])
car_data6.head()
# Out:
#   Dealer's Price:         MSRP:                    Location:  Mileage:  \
# 0         $50,453  Not Provided       Boerne, TX\n25 mi away       ---
# 1         $54,796       $54,796   San Antonio, TX\n8 mi away   0 miles
# 2         $55,317       $55,317  San Antonio, TX\n10 mi away  10 miles
# 3         $58,469       $58,469   San Antonio, TX\n8 mi away   0 miles
# 4         $58,640       $58,640      Laredo, TX\n145 mi away   0 miles
#
#   Transmission:                   Exterior Color:     Interior Color:  \
# 0     Automatic                              Gray  Black (Blk Fabric)
# 1     Automatic                             Black                 NaN
# 2     Automatic                     Magnetic Gray     Gray (GRAPHITE)
# 3     Automatic                              Blue                 NaN
# 4     Automatic  Silver (MIDNIGHT-BLACK METALLIC)                 NaN
#
#                              Est. Gas Mileage*:                Engine:  \
# ...

# %%
len(car_data6)
# Out:
# 145

# %%
csv_file = '../Resources/1200-1400.csv'
car_data7 = pd.read_csv(csv_file)
car_data7 = car_data7.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data7.head()
# Out:
#   Make:    Model:  Year:               Trim:       Body type:  \
# 0  Jeep  Wrangler   2022           Sport 4WD  SUV / crossover
# 1  Jeep  Wrangler   2022          Willys 4WD  SUV / crossover
# 2  Jeep  Wrangler   2022  Sport Altitude 4WD  SUV / crossover
# 3  Jeep  Wrangler   2022  Sport Altitude 4WD  SUV / crossover
# 4  Jeep  Wrangler   2022         Sport S 4WD  SUV / crossover
#
#                           Exterior color: Interior color: Mileage:  \
# 0  Brown (Limited Edition Gobi Clearcoat)           Black     0 mi
# 1                            Bright White           Black     0 mi
# 2                                    Gray           Black     0 mi
# 3                                   Black           Black     0 mi
# 4                    Sting-Gray Clearcoat           Black     7 mi
#
#                 VIN:   Price:  \
# 0  1C4HJXDN6NW243959  $40,359
# 1  1C4HJXDNXNW253569  $42,125
# 2  1C4HJXDN8NW242280  $43,379
# 3  1C4HJXDG9NW226056  $43,879
# ...

# %%
len(car_data7)
# Out:
# 170

# %%
csv_file = '../Resources/1400-1600.csv'
car_data8 = pd.read_csv(csv_file)
car_data8 = car_data8.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data8.head()
# Out:
#   Make:    Model:  Year:        Trim:       Body type:  \
# 0  Jeep  Wrangler   2022  Rubicon 4WD  SUV / crossover
# 1  Jeep  Wrangler   2022  Rubicon 4WD  SUV / crossover
# 2  Jeep  Wrangler   2022  Rubicon 4WD  SUV / crossover
# 3  Jeep  Wrangler   2022  Rubicon 4WD  SUV / crossover
# 4  Jeep  Wrangler   2022  Rubicon 4WD  SUV / crossover
#
#              Exterior color: Interior color: Mileage:               VIN:  \
# 0     Bright White Clearcoat           Black    15 mi  1C4JJXR61NW152861
# 1       Sting-Gray Clearcoat           Black      NaN  1C4JJXR66NW214819
# 2      Sarge Green Clearcoat           Black      NaN  1C4JJXR6XNW239562
# 3            Black Clearcoat           Black      NaN  1C4JJXR6XNW245653
# 4  Firecracker Red Clearcoat           Black     0 mi  1C4JJXR62NW222268
#
#     Price:                         Dealer Name:  \
# 0  $68,237               Premier CDJR of Lamesa
# 1  $68,501                           Mark Dodge
# ...

# %%
len(car_data8)
# Out:
# 175

# %%
csv_file = '../Resources/1600-1800.csv'
car_data9 = pd.read_csv(csv_file)
car_data9 = car_data9.drop(columns=['Stock number:', 
                                    'Unnamed: 0'])
car_data9.head()
# Out:
#   Make:    Model:  Year:                   Trim:       Body type:  \
# 0  Ford    Bronco   2022  Outer Banks 4-Door 4WD  SUV / crossover
# 1  Ford  Maverick   2022                     NaN            Coupe
# 2  Ford  Maverick   2022                     NaN            Coupe
# 3  Ford  Maverick   2022                     NaN            Coupe
# 4  Ford  Maverick   2022                     NaN            Coupe
#
#                             Exterior color:                Interior color:  \
# 0  Hot Pepper Red Metallic Tinted Clearcoat             Roast w/Black Onyx
# 1                        Gray (Cactus Grey)          Black Onyx/Dark Slate
# 2                    Velocity Blue Metallic                   Desert Brown
# 3       Alto Blue Tinted Clearcoat Metallic  Blue (Navy Pier/Medium Slate)
# 4                        Gray (Cactus Grey)          Black Onyx/Dark Slate
#
#   Mileage:               VIN:   Price:          Dealer Name:  \
# ...

# %%
len(car_data9)
# Out:
# 167

# %%
csv_file = '../Resources/1800-2000.csv'
car_data10 = pd.read_csv(csv_file)
car_data10 = car_data10.drop(columns=['Unnamed: 0'])
car_data10.head()
# Out:
#   Make:    Model:  Year:               Trim:       Body type:  \
# 0  Jeep  Wrangler   2022         Sport S 4WD  SUV / crossover
# 1  Jeep  Wrangler   2022  Sport Altitude 4WD  SUV / crossover
# 2  Jeep  Wrangler   2022         Sport S 4WD  SUV / crossover
# 3  Jeep  Wrangler   2022  Sport Altitude 4WD  SUV / crossover
# 4  Jeep  Wrangler   2022          Willys 4WD  SUV / crossover
#
#                              Exterior color: Interior color: Mileage:  \
# 0  Gray (Granite Crystal Metallic Clearcoat)           Black     5 mi
# 1                            Black Clearcoat           Black     0 mi
# 2                     Bright White Clearcoat           Black    20 mi
# 3                  Firecracker Red Clearcoat           Black     0 mi
# 4                     Bright White Clearcoat           Black     0 mi
#
#                 VIN: Stock number:   Price:  \
# 0  1C4HJXDN8NW204340      NW204340  $44,030
# 1  1C4HJXDN6NW211996      NW211996  $44,325
# ...

# %%
len(car_data10)
# Out:
# 179

# %%
csv_file = '../Resources/2000-2221.csv'
car_data11 = pd.read_csv(csv_file)
car_data11 = car_data11.drop(columns=['Stock #:', 
                                      'Unnamed: 0',
                                      'Delivery:', 
                                      'Price + Delivery:'])
car_data11
# Out:
#     Dealer's Price:         MSRP:                      Location:   Mileage:  \
# 0           $54,880       $58,280        Houston, TX\n18 mi away    0 miles
# 1           $54,880       $58,280        Houston, TX\n18 mi away    0 miles
# 2           $54,887       $56,980  Lake Charles, LA\n134 mi away        ---
# 3           $54,973       $57,075  Lake Charles, LA\n134 mi away        ---
# 4           $54,981       $57,085  Lake Charles, LA\n134 mi away        ---
# ..              ...           ...                            ...        ...
# 171         $68,600       $68,600         Conroe, TX\n45 mi away    5 miles
# 172         $68,748       $67,253       Richmond, TX\n23 mi away   10 miles
# 173         $78,001       $78,001         Conroe, TX\n45 mi away    6 miles
# 174         $78,426       $78,426         Houston, TX\n5 mi away        ---
# 175         $78,990  Not Provided        Houston, TX\n11 mi away  248 miles
#
#          Transmission:         Exterior Color:  \
# ...

# %%
len(car_data11)
# Out:
# 176

# %%
all_scraping_data = pd.concat([car_data1, car_data2, car_data3, car_data4, 
                          car_data5, car_data6, car_data7, car_data8,
                         car_data9, car_data10, car_data11])
all_scraping_data = all_scraping_data.drop(columns=['Stock number:'])

all_scraping_data.head()
# Out:
#   Make:  Model:   Year:       Body type:          Exterior color:  \
# 0  Ford  Bronco  2022.0  SUV / crossover                 Race Red
# 1  Ford  Bronco  2022.0  SUV / crossover              CACTUS GRAY
# 2  Ford  Bronco  2022.0  SUV / crossover           Blue (Area 51)
# 3  Ford  Bronco  2022.0  SUV / crossover           Blue (AREA 51)
# 4  Ford  Bronco  2022.0  SUV / crossover  HOT Pepper Red MET Tint
#
#                                  Interior color: Mileage:               VIN:  \
# 0                                       Red (Pv)    15 mi  1FMDE5CP9NLB31549
# 1                                    STONE/BLACK     0 mi  1FMEE5DP8NLB35076
# 2  CLOTH SANDSTONE/BLK SEATS BLACK ONYX INTERIOR     0 mi  1FMDE5AH3NLB11244
# 3                                     GRAY/BLACK     0 mi  1FMDE5BH9NLB12171
# 4                                Dark Space Gray     0 mi  1FMDE5BH2NLA84536
#
#     Price:        Dealer Name:  ... Exterior Color: Interior Color:  \
# ...

# %%
len(all_scraping_data)
# Out:
# 1846

# %%
all_scraping_data.to_csv('../Resources/all_scraping_data2.csv', index=False)

# %%
csv_file = '../Resources/all_scraping_data2.csv'
all_scraping_data2 = pd.read_csv(csv_file)
all_scraping_data2.head()
# Out:
#   Make:  Model:   Year:       Body type:          Exterior color:  \
# 0  Ford  Bronco  2022.0  SUV / crossover                 Race Red
# 1  Ford  Bronco  2022.0  SUV / crossover              CACTUS GRAY
# 2  Ford  Bronco  2022.0  SUV / crossover           Blue (Area 51)
# 3  Ford  Bronco  2022.0  SUV / crossover           Blue (AREA 51)
# 4  Ford  Bronco  2022.0  SUV / crossover  HOT Pepper Red MET Tint
#
#                                  Interior color: Mileage:               VIN:  \
# 0                                       Red (Pv)    15 mi  1FMDE5CP9NLB31549
# 1                                    STONE/BLACK     0 mi  1FMEE5DP8NLB35076
# 2  CLOTH SANDSTONE/BLK SEATS BLACK ONYX INTERIOR     0 mi  1FMDE5AH3NLB11244
# 3                                     GRAY/BLACK     0 mi  1FMDE5BH9NLB12171
# 4                                Dark Space Gray     0 mi  1FMDE5BH2NLA84536
#
#     Price:        Dealer Name:  ... Exterior Color: Interior Color:  \
# ...

# %%
# rename columns
# all_scraping_data2=all_scraping_data2.replace({
#     "Interior Color:":"Interior Color",
#     "Interior color:":"Interior Color",
    
#     "Exterior Color:":"Exterior Color",
#     "Exterior color:":"Exterior Color",
    
#     "Dealer Address:":"Dealer Address",
#     "Location:":"Dealer Address",
    
#     "Dealer's Price:":"Dealer's Price",
#     "Price:":"Dealer's Price"
# })
# all_scraping_data2.head()

# %%
# all_scraping_data2['Address:'] = ""

# for index, row in all_scraping_data2.iterrows():
#     if len(row["Dealer Address:"]) >5:
#         row['Address:'] = row["Dealer Address:"]
#     elif len(row["Location:"]) >5:
#         row['Address:'] = row["Location:"]
# all_scraping_data2.head()

# %%
all_scraping_data2.columns
# Out:
# Index(['Make:', 'Model:', 'Year:', 'Body type:', 'Exterior color:',
#        'Interior color:', 'Mileage:', 'VIN:', 'Price:', 'Dealer Name:',
#        'Dealer Address:', 'Trim:', 'Dealer's Price:', 'MSRP:', 'Location:',
#        'Transmission:', 'Exterior Color:', 'Interior Color:',
#        'Est. Gas Mileage*:', 'Battery Performance:', 'Engine:', 'Drivetrain:',
#        'Fuel Type:', 'Condition:', 'Cabin Size:',
#        'NHTSA Overall Safety Rating:'],
#       dtype='object')

# %%
# all_scraping_data2['Address:'] = ""

# for index, row in all_scraping_data2.iterrows():
#     if len(row["Dealer Address:"]) != None:
#         row['Address:'] = row["Dealer Address:"]
#     elif len(row["Location:"]) != None:
#         row['Address:'] = row["Location:"]

# all_scraping_data2[['Address:', 'Dealer Address:', "Location:"]]

# %%
# all_scraping_data2['Address:'] = ""

# for index, row in all_scraping_data2.iterrows():
#     if "TX" in row["Dealer Address:"]:
#         row['Address:'] = row["Dealer Address:"]
#     elif "TX" in row["Location:"]:
#         row['Address:'] = row["Location:"]

# all_scraping_data2[['Address:', 'Dealer Address:', "Location:"]]

# %%
all_scraping_data2 = all_scraping_data2.loc[all_scraping_data2["Dealer Address:"].str.contains('TX')]
all_scraping_data2.head()
# Out:
#   Make:  Model:   Year:       Body type:          Exterior color:  \
# 0  Ford  Bronco  2022.0  SUV / crossover                 Race Red
# 1  Ford  Bronco  2022.0  SUV / crossover              CACTUS GRAY
# 2  Ford  Bronco  2022.0  SUV / crossover           Blue (Area 51)
# 3  Ford  Bronco  2022.0  SUV / crossover           Blue (AREA 51)
# 4  Ford  Bronco  2022.0  SUV / crossover  HOT Pepper Red MET Tint
#
#                                  Interior color: Mileage:               VIN:  \
# 0                                       Red (Pv)    15 mi  1FMDE5CP9NLB31549
# 1                                    STONE/BLACK     0 mi  1FMEE5DP8NLB35076
# 2  CLOTH SANDSTONE/BLK SEATS BLACK ONYX INTERIOR     0 mi  1FMDE5AH3NLB11244
# 3                                     GRAY/BLACK     0 mi  1FMDE5BH9NLB12171
# 4                                Dark Space Gray     0 mi  1FMDE5BH2NLA84536
#
#     Price:        Dealer Name:  ... Exterior Color: Interior Color:  \
# ...

# %%
# all_scraping_data2 = all_scraping_data2.drop(columns=[#'Location:',
#                                                      'NHTSA Overall Safety Rating:',
#                                                      'Interior Color:',
#                                                       'Est. Gas Mileage*:',
#                                                       'Battery Performance:',
#                                                       'Engine:',
#                                                       'Drivetrain:',
#                                                       'Fuel Type:',
#                                                       'Condition:',
#                                                       'Cabin Size:',
#                                                       'NHTSA Overall Safety Rating:',
#                                                       'Address:'])
# all_scraping_data2

# %%
all_scraping_data3 = all_scraping_data2
all_scraping_data3
# Out:
#      Make:  Model:   Year:       Body type:          Exterior color:  \
# 0     Ford  Bronco  2022.0  SUV / crossover                 Race Red
# 1     Ford  Bronco  2022.0  SUV / crossover              CACTUS GRAY
# 2     Ford  Bronco  2022.0  SUV / crossover           Blue (Area 51)
# 3     Ford  Bronco  2022.0  SUV / crossover           Blue (AREA 51)
# 4     Ford  Bronco  2022.0  SUV / crossover  HOT Pepper Red MET Tint
# ...    ...     ...     ...              ...                      ...
# 1841   NaN  Tundra     NaN              NaN                      NaN
# 1842   NaN  Tundra     NaN              NaN                      NaN
# 1843   NaN  Tundra     NaN              NaN                      NaN
# 1844   NaN  Tundra     NaN              NaN                      NaN
# 1845   NaN  Tundra     NaN              NaN                      NaN
#
#                                     Interior color:   Mileage:  \
# 0                                          Red (Pv)      15 mi
# ...

# %%
all_scraping_data3 = all_scraping_data2.dropna(subset=['MSRP:'])
all_scraping_data3
# Out:
#      Make:    Model:  Year: Body type: Exterior color: Interior color:  \
# 527    NaN  Wrangler    NaN        NaN             NaN             NaN
# 528    NaN  Wrangler    NaN        NaN             NaN             NaN
# 530    NaN  Wrangler    NaN        NaN             NaN             NaN
# 534    NaN  Wrangler    NaN        NaN             NaN             NaN
# 535    NaN  Wrangler    NaN        NaN             NaN             NaN
# ...    ...       ...    ...        ...             ...             ...
# 1841   NaN    Tundra    NaN        NaN             NaN             NaN
# 1842   NaN    Tundra    NaN        NaN             NaN             NaN
# 1843   NaN    Tundra    NaN        NaN             NaN             NaN
# 1844   NaN    Tundra    NaN        NaN             NaN             NaN
# 1845   NaN    Tundra    NaN        NaN             NaN             NaN
#
#        Mileage:               VIN:   Price:  \
# 527    15 miles  1C4JJXR61NW152861  $68,218
# ...

# %%
all_scraping_data4 = all_scraping_data3.drop(columns=['Exterior color:',
                                                      'Interior color:',
                                                      'Exterior Color:'])
all_scraping_data4
# Out:
#      Make:    Model:  Year: Body type:   Mileage:               VIN:   Price:  \
# 527    NaN  Wrangler    NaN        NaN   15 miles  1C4JJXR61NW152861  $68,218
# 528    NaN  Wrangler    NaN        NaN        ---  1C4JJXR64NW108322  $69,920
# 530    NaN  Wrangler    NaN        NaN    3 miles  1C4JJXR6XNW108101  $68,700
# 534    NaN  Wrangler    NaN        NaN        ---  1C4JJXR62NW270773  $70,475
# 535    NaN  Wrangler    NaN        NaN        ---  1C4JJXR61NW274197  $70,870
# ...    ...       ...    ...        ...        ...                ...      ...
# 1841   NaN    Tundra    NaN        NaN    5 miles  5TFPC5DB5NX004915  $68,600
# 1842   NaN    Tundra    NaN        NaN   10 miles  5TFMA5DB6NX034823  $68,748
# 1843   NaN    Tundra    NaN        NaN    6 miles  5TFVC5DB5NX002511  $78,001
# 1844   NaN    Tundra    NaN        NaN        ---  5TFVC5DB8NX002583  $78,426
# 1845   NaN    Tundra    NaN        NaN  248 miles  5TFLA5DB1NX019691  $78,990
#
# ...

# %%
all_scraping_data5 = all_scraping_data4.drop(columns=['Trim:'])
all_scraping_data5
# Out:
#      Make:    Model:  Year: Body type:   Mileage:               VIN:   Price:  \
# 527    NaN  Wrangler    NaN        NaN   15 miles  1C4JJXR61NW152861  $68,218
# 528    NaN  Wrangler    NaN        NaN        ---  1C4JJXR64NW108322  $69,920
# 530    NaN  Wrangler    NaN        NaN    3 miles  1C4JJXR6XNW108101  $68,700
# 534    NaN  Wrangler    NaN        NaN        ---  1C4JJXR62NW270773  $70,475
# 535    NaN  Wrangler    NaN        NaN        ---  1C4JJXR61NW274197  $70,870
# ...    ...       ...    ...        ...        ...                ...      ...
# 1841   NaN    Tundra    NaN        NaN    5 miles  5TFPC5DB5NX004915  $68,600
# 1842   NaN    Tundra    NaN        NaN   10 miles  5TFMA5DB6NX034823  $68,748
# 1843   NaN    Tundra    NaN        NaN    6 miles  5TFVC5DB5NX002511  $78,001
# 1844   NaN    Tundra    NaN        NaN        ---  5TFVC5DB8NX002583  $78,426
# 1845   NaN    Tundra    NaN        NaN  248 miles  5TFLA5DB1NX019691  $78,990
#
# ...

# %%
all_scraping_data6 = all_scraping_data5.drop(columns=['Body type:'])
all_scraping_data6
# Out:
#      Make:    Model:  Year:   Mileage:               VIN:   Price:  \
# 527    NaN  Wrangler    NaN   15 miles  1C4JJXR61NW152861  $68,218
# 528    NaN  Wrangler    NaN        ---  1C4JJXR64NW108322  $69,920
# 530    NaN  Wrangler    NaN    3 miles  1C4JJXR6XNW108101  $68,700
# 534    NaN  Wrangler    NaN        ---  1C4JJXR62NW270773  $70,475
# 535    NaN  Wrangler    NaN        ---  1C4JJXR61NW274197  $70,870
# ...    ...       ...    ...        ...                ...      ...
# 1841   NaN    Tundra    NaN    5 miles  5TFPC5DB5NX004915  $68,600
# 1842   NaN    Tundra    NaN   10 miles  5TFMA5DB6NX034823  $68,748
# 1843   NaN    Tundra    NaN    6 miles  5TFVC5DB5NX002511  $78,001
# 1844   NaN    Tundra    NaN        ---  5TFVC5DB8NX002583  $78,426
# 1845   NaN    Tundra    NaN  248 miles  5TFLA5DB1NX019691  $78,990
#
#                                      Dealer Name:  \
# 527                        Premier CDJR of Lamesa
# 528   Shottenkirk Prosper Chrysler Dodge Jeep Ram
# ...

# %%
all_scraping_data6.to_csv('../Resources/all_scraping_data3.csv', index=False)

# %%
#rename
all_scraping_data6.rename(columns = {'MSRP:':'MSRP',
                                       "Dealer's Price:":"Dealer's Price",
                                       'Price:':'Price',
                                       'Make:':'Make',
                                       'Model:':'Model',
                                       'Year:':'Year',
                                       'Transmission:':'Transmission',
                                       'Mileage:':'Mileage',
                                       'Dealer Name:':'Dealer Name',
                                       'Dealer Address:':'Dealer Address',
                                        'VIN:':'VIN Number'
                                        }, inplace = True)
all_scraping_data6
# Out:
#      Make     Model  Year    Mileage         VIN Number    Price  \
# 527   NaN  Wrangler   NaN   15 miles  1C4JJXR61NW152861  $68,218
# 528   NaN  Wrangler   NaN        ---  1C4JJXR64NW108322  $69,920
# 530   NaN  Wrangler   NaN    3 miles  1C4JJXR6XNW108101  $68,700
# 534   NaN  Wrangler   NaN        ---  1C4JJXR62NW270773  $70,475
# 535   NaN  Wrangler   NaN        ---  1C4JJXR61NW274197  $70,870
# ...   ...       ...   ...        ...                ...      ...
# 1841  NaN    Tundra   NaN    5 miles  5TFPC5DB5NX004915  $68,600
# 1842  NaN    Tundra   NaN   10 miles  5TFMA5DB6NX034823  $68,748
# 1843  NaN    Tundra   NaN    6 miles  5TFVC5DB5NX002511  $78,001
# 1844  NaN    Tundra   NaN        ---  5TFVC5DB8NX002583  $78,426
# 1845  NaN    Tundra   NaN  248 miles  5TFLA5DB1NX019691  $78,990
#
#                                       Dealer Name  \
# 527                        Premier CDJR of Lamesa
# 528   Shottenkirk Prosper Chrysler Dodge Jeep Ram
# ...

# %%
#reorder columns
all_scraping_data7 = all_scraping_data6[['VIN Number',
                                         'MSRP',
                                         "Dealer's Price",
                                         'Price',
                                         'Make',
                                         'Model',
                                         'Year',
                                         'Transmission',
                                         'Mileage',
                                         'Dealer Name',
                                         'Dealer Address',]]
all_scraping_data7
# Out:
#              VIN Number          MSRP Dealer's Price    Price Make     Model  \
# 527   1C4JJXR61NW152861       $67,935        $67,935  $68,218  NaN  Wrangler
# 528   1C4JJXR64NW108322       $69,920        $69,920  $69,920  NaN  Wrangler
# 530   1C4JJXR6XNW108101       $68,700        $68,700  $68,700  NaN  Wrangler
# 534   1C4JJXR62NW270773       $70,475        $70,475  $70,475  NaN  Wrangler
# 535   1C4JJXR61NW274197       $70,870        $70,870  $70,870  NaN  Wrangler
# ...                 ...           ...            ...      ...  ...       ...
# 1841  5TFPC5DB5NX004915       $68,600        $68,600  $68,600  NaN    Tundra
# 1842  5TFMA5DB6NX034823       $67,253        $68,748  $68,748  NaN    Tundra
# 1843  5TFVC5DB5NX002511       $78,001        $78,001  $78,001  NaN    Tundra
# 1844  5TFVC5DB8NX002583       $78,426        $78,426  $78,426  NaN    Tundra
# 1845  5TFLA5DB1NX019691  Not Provided        $78,990  $78,990  NaN    Tundra
#
#       Year       Transmission    Mileage  \
# ...

# %%
all_scraping_data7['Year'] = all_scraping_data7['Year'].fillna(2022)
all_scraping_data7
# Out:
# /var/folders/nk/670c2l4j02j1x3bk4kcm7qh80000gn/T/ipykernel_23333/111397104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_scraping_data7['Year'] = all_scraping_data7['Year'].fillna(2022)
#              VIN Number          MSRP Dealer's Price    Price Make     Model  \
# 527   1C4JJXR61NW152861       $67,935        $67,935  $68,218  NaN  Wrangler
# 528   1C4JJXR64NW108322       $69,920        $69,920  $69,920  NaN  Wrangler
# 530   1C4JJXR6XNW108101       $68,700        $68,700  $68,700  NaN  Wrangler
# 534   1C4JJXR62NW270773       $70,475        $70,475  $70,475  NaN  Wrangler
# 535   1C4JJXR61NW274197       $70,870        $70,870  $70,870  NaN  Wrangler
# ...

# %%
all_scraping_data7.to_csv('../Resources/all_scraping_data4.csv', index=False)

# %%
csv_file = '../Resources/all_scraping_data5.csv'
all_scraping_data8 = pd.read_csv(csv_file)
all_scraping_data8
# Out:
#              MSRP Dealer's Price     Price    Make     Model  Year  \
# 0        $67,935        $67,935   $68,218     Jeep  Wrangler  2022
# 1        $69,920        $69,920   $69,920     Jeep  Wrangler  2022
# 2        $68,700        $68,700   $68,700     Jeep  Wrangler  2022
# 3        $70,475        $70,475   $70,475     Jeep  Wrangler  2022
# 4        $70,870        $70,870   $70,870     Jeep  Wrangler  2022
# ..            ...            ...       ...     ...       ...   ...
# 389      $68,600        $68,600   $68,600   Toyota    Tundra  2022
# 390      $67,253        $68,748   $68,748   Toyota    Tundra  2022
# 391      $78,001        $78,001   $78,001   Toyota    Tundra  2022
# 392      $78,426        $78,426   $78,426   Toyota    Tundra  2022
# 393  Not Provided       $78,990   $78,990   Toyota    Tundra  2022
#
#           Transmission    Mileage  \
# 0    8-Speed Automatic   15 miles
# 1    8-Speed Automatic        ---
# 2    8-Speed Automatic    3 miles
# ...

# %%
all_scraping_data8.to_csv('../Resources/all_scraping_data6.csv', index=False)

# %%
csv_file = '../Resources/all_scraping_data7.csv'
all_scraping_data9 = pd.read_csv(csv_file)
all_scraping_data9
# Out:
#              MSRP Dealer's Price     Price    Make     Model  Year  \
# 0        $67,935        $67,935   $68,218     Jeep  Wrangler  2022
# 1        $69,920        $69,920   $69,920     Jeep  Wrangler  2022
# 2        $68,700        $68,700   $68,700     Jeep  Wrangler  2022
# 3        $70,475        $70,475   $70,475     Jeep  Wrangler  2022
# 4        $70,870        $70,870   $70,870     Jeep  Wrangler  2022
# ..            ...            ...       ...     ...       ...   ...
# 389      $68,600        $68,600   $68,600   Toyota    Tundra  2022
# 390      $67,253        $68,748   $68,748   Toyota    Tundra  2022
# 391      $78,001        $78,001   $78,001   Toyota    Tundra  2022
# 392      $78,426        $78,426   $78,426   Toyota    Tundra  2022
# 393  Not Provided       $78,990   $78,990   Toyota    Tundra  2022
#
#           Transmission    Mileage  \
# 0    8-Speed Automatic   15 miles
# 1    8-Speed Automatic        ---
# 2    8-Speed Automatic    3 miles
# ...

# %%
csv_file = '../Resources/All Scraping Data/all_scraping_data7.csv'
all_scraping_data20 = pd.read_csv(csv_file)
all_scraping_data20
# Out:
#                    vin   msrp  dealer's price  price    make     model  year  \
# 0    1C4JJXR61NW152861  67935           67935  68218    Jeep  Wrangler  2022
# 1    1C4JJXR64NW108322  69920           69920  69920    Jeep  Wrangler  2022
# 2    1C4JJXR6XNW108101  68700           68700  68700    Jeep  Wrangler  2022
# 3    1C4JJXR62NW270773  70475           70475  70475    Jeep  Wrangler  2022
# 4    1C4JJXR61NW274197  70870           70870  70870    Jeep  Wrangler  2022
# ..                 ...    ...             ...    ...     ...       ...   ...
# 389  5TFPC5DB5NX004915  68600           68600  68600  Toyota    Tundra  2022
# 390  5TFMA5DB6NX034823  67253           68748  68748  Toyota    Tundra  2022
# 391  5TFVC5DB5NX002511  78001           78001  78001  Toyota    Tundra  2022
# 392  5TFVC5DB8NX002583  78426           78426  78426  Toyota    Tundra  2022
# 393  5TFLA5DB1NX019691  78990           78990  78990  Toyota    Tundra  2022
#
#           transmission    mileage  \
# ...

# %%
all_scraping_data21 = all_scraping_data20.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
all_scraping_data21
# Out:
#                    vin   msrp  dealer's price  price    make     model  year  \
# 0    1C4JJXR61NW152861  67935           67935  68218    Jeep  Wrangler  2022
# 1    1C4JJXR64NW108322  69920           69920  69920    Jeep  Wrangler  2022
# 2    1C4JJXR6XNW108101  68700           68700  68700    Jeep  Wrangler  2022
# 3    1C4JJXR62NW270773  70475           70475  70475    Jeep  Wrangler  2022
# 4    1C4JJXR61NW274197  70870           70870  70870    Jeep  Wrangler  2022
# ..                 ...    ...             ...    ...     ...       ...   ...
# 389  5TFPC5DB5NX004915  68600           68600  68600  Toyota    Tundra  2022
# 390  5TFMA5DB6NX034823  67253           68748  68748  Toyota    Tundra  2022
# 391  5TFVC5DB5NX002511  78001           78001  78001  Toyota    Tundra  2022
# 392  5TFVC5DB8NX002583  78426           78426  78426  Toyota    Tundra  2022
# 393  5TFLA5DB1NX019691  78990           78990  78990  Toyota    Tundra  2022
#
#           transmission    mileage  \
# ...

# %%
len(all_scraping_data21)
# Out:
# 389

# %%
all_scraping_data21.to_csv('../Resources/All Scraping Data/all_scraping_data7.csv', index=False)
