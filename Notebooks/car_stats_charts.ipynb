# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
car_df = pd.read_csv("../Resources/Data Sources/reduced_auto_df.csv")



# bed = car_df["BedLengthIN"]

# bed

# for b in range(len(bed)):
#     if not ("NaN") in bed:
#         print("not nan")

# %%
car_stats = car_df.describe().round(2)

car_stats
# Out:
#              MSRP  Selling_Price    Mileage     Axles  BasePrice  BedLengthIN  \
# count   157402.00      157402.00  157402.00  102373.0   75839.00       365.00
# mean     37503.75       34456.18       0.68       2.0   31279.85        67.00
# std      36279.22       31618.23       3.93       0.0   14015.94         4.79
# min          0.00           0.00       0.00       2.0      13.90        61.00
# 25%      24195.00       21972.00       0.00       2.0   22500.00        64.00
# 50%      33400.00       30860.00       0.00       2.0   26300.00        67.00
# 75%      49365.00       44722.00       0.00       2.0   37495.00        67.00
# max    5877140.00     5877140.00     100.00       2.0  187500.00        79.00
#
#            Doors  EngineHP  ModelYear  TopSpeedMPH  TransmissionSpeeds
# count  124442.00  96781.00  157399.00     45089.00            44752.00
# mean        3.92    252.74    2018.86       133.13                6.98
# ...

# %%
reduced_df = car_df.head(1000)
# df = pd.DataFrame({"Model", 'val':[10, 30, 20]})
ax = reduced_df.plot.bar(x='Model', y='Selling_Price', rot=0)
# Out:
# <AxesSubplot:xlabel='Model'>

# %%
selling = car_df["Selling_Price"]

pd.DataFrame(selling)
# Out:
#         Selling_Price
# 0               41659
# 1               47174
# 2               12568
# 3               12568
# 4               19514
# ...               ...
# 157397          21291
# 157398          21316
# 157399          28467
# 157400          19368
# 157401          21800
#
# [157402 rows x 1 columns]

# %%
Model_groupby = car_df.groupby(by=["Model"], dropna=False, as_index=False).mean().round(2)

Model_groupby
# Out:
#           Model       MSRP  Selling_Price  Mileage  Axles  BasePrice  \
# 0    124 Spider   31713.08       30403.41     2.16    2.0        NaN
# 1          1500   47986.93       41741.20     0.67    2.0        NaN
# 2          230i   44631.45       44476.35     2.07    2.0   40423.08
# 3          2500   53426.29       49216.71     0.95    2.0   52795.00
# 4           300   32344.35       28396.57     0.40    2.0   32962.93
# ..          ...        ...            ...      ...    ...        ...
# 226    Yaris iA   16650.83       16118.30     0.04    2.0   15950.00
# 227          Z4   63019.22       63019.22     1.57    2.0   49700.00
# 228          i3   52590.00       52590.00     0.00    2.0   48555.00
# 229          i8  169965.00      169965.00     2.50    2.0  147500.00
# 230         NaN   71919.19       70990.55     1.01    NaN        NaN
#
#      BedLengthIN  Doors  EngineHP  ModelYear  TopSpeedMPH  TransmissionSpeeds
# ...

# %%
ax = reduced_df.plot.scatter(x='MSRP', y='Selling_Price', rot=0)

# %%
MSRP_By_Model = Model_groupby["MSRP"].value_counts()
Selling_By_Model = Model_groupby["Selling_Price"].value_counts()
Selling_By_Model
# Out:
# 30403.41    1
# 25823.22    1
# 15910.84    1
# 50150.02    1
# 36688.89    1
#            ..
# 31712.47    1
# 19420.58    1
# 71809.78    1
# 18156.14    1
# 70990.55    1
# Name: Selling_Price, Length: 231, dtype: int64

# %%
ax = Model_groupby.plot.bar(x='Model', y='Selling_Price', rot=0)

# %%
counts = car_df[''].value_counts()
plt.bar(counts.index.values,counts.values)

plt.xticks(rotation=90)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.bar(counts.index.Selling_By_Model ,model1.values)

plt.show()

# %%
mean_car = Model_groupby.mean().round(2)

courses = list(Model_groupby.keys())
#values = list(Model_groupby.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
mean_car.bar.count()

plt.show()
